# %%
import os
import numpy as np
import pandas as pd
import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.time import Time
from tqdm import tqdm
import matplotlib.pyplot as plt

from tess_asteroid_ml import *
from tess_asteroid_ml.make_TESS_asteroid_db import *
# Out:
# /Users/jimartin/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/lightkurve/prf/__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
# ccd = 1
provider = "mast"

for sector in range(40, 46):
    for camera in range(2, 5):
        for ccd in range(1, 4):

            print(f"Sector {sector} Camera {camera}")
            # get FFI file path
            try:
                ffi_file = get_FFI_name(sector=sector, camera=camera, ccd=ccd, provider=provider, correct=0)
                print(ffi_file)
                # read FFI to get time, WCS and header
                ffi_header, f2d, col_2d, row_2d, ra_2d, dec_2d = get_data_from_files(
                    ffi_file, provider=provider
                )
            except:
                ffi_file = get_FFI_name(sector=sector, camera=camera, ccd=ccd, provider=provider, correct=1)
                print(ffi_file)
                # read FFI to get time, WCS and header
                ffi_header, f2d, col_2d, row_2d, ra_2d, dec_2d = get_data_from_files(
                    ffi_file, provider=provider
                )
            
            ffi_date = get_sector_dates(sector=sector)
    
            # get asteroid table from JPL SBI for Sector/Camera/CCD
            try:
                edge1 = SkyCoord(np.min(ra_2d) * u.deg, 
                         np.min(dec_2d) * u.deg, 
                         frame='icrs')
                edge2 = SkyCoord(np.max(ra_2d) * u.deg, 
                                 np.max(dec_2d) * u.deg, 
                                 frame='icrs')
            except ValueError:
                print("This sector/camera has a CCD with bad WCS. NEED to CHECK...")
                continue
            # if sector raps around ra 360/0 edge find the right sector edges
            if np.abs(edge1.ra - edge2.ra) > 180 * u.deg and np.max(np.abs(dec_2d)) < 89:
                ra_2d = np.array(ra_2d)
                edge1 = SkyCoord(np.min(ra_2d[ra_2d >180]) * u.deg, 
                     np.min(dec_2d) * u.deg, 
                     frame='icrs')
                edge2 = SkyCoord(np.max(ra_2d[ra_2d < 180]) * u.deg, 
                                 np.max(dec_2d) * u.deg, 
                                 frame='icrs')
            plt.scatter(ra_2d, dec_2d, s=1)
            plt.scatter(edge1.ra, edge1.dec, marker="*", s=4)
            plt.scatter(edge2.ra, edge2.dec, marker="*", s=4)
            plt.title(f"Sector {sector} camera {camera} ccd {ccd}")
            plt.show()
            try:
                jpl_df = get_asteroid_table(
                    edge1, 
                    edge2, 
                    sector=sector, 
                    camera=camera, 
                    ccd=ccd, 
                    date_obs=np.linspace(ffi_date.jd.min(), ffi_date.jd.max(), 5), 
                    force=True, 
                    elem=True,
                    sb_kind="all",
                )
                jpl_df = get_asteroid_table(
                    edge1, 
                    edge2, 
                    sector=sector, 
                    camera=camera, 
                    ccd=ccd, 
                    date_obs=np.linspace(ffi_date.jd.min(), ffi_date.jd.max(), 5), 
                    force=True, 
                    elem=False,
                    sb_kind="all",
                )
            except ValueError:
                print("This sector/camera had empty JPL result. NEED to CHECK...")
                # break
                continue
            print("======" * 10)
        #     break
        # break
# Out:
# Sector 40 Camera 2
# ['https://archive.stsci.edu/missions/tess/ffi/s0040/2021/185/2-1/tess2021185054902-s0040-2-1-0211-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59399.243404 from DATE-OBS.
# Set MJD-END to 59399.250348 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459390.6521064816 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459397.70245081 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459404.752795139 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459411.8031394677 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459418.853483796 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-2-1_catalog_elem.csv
# JPL SBI found 31 asteroids with V < 30 in s0040-2-1
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459390.6521064816 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459397.70245081 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459404.752795139 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459411.8031394677 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (273.77756933, 50.34118036)> <SkyCoord (ICRS): (ra, dec) in deg
#     (298.05365973, 62.61152128)> 2459418.853483796 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-2-1_catalog.csv
# JPL SBI found 31 asteroids with V < 30 in s0040-2-1
# ============================================================
# Sector 40 Camera 2
# ['https://archive.stsci.edu/missions/tess/ffi/s0040/2021/185/2-2/tess2021185054902-s0040-2-2-0211-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59399.243514 from DATE-OBS.
# Set MJD-END to 59399.250458 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459390.6521064816 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459397.70245081 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459404.752795139 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459411.8031394677 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459418.853483796 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-2-2_catalog_elem.csv
# JPL SBI found 31 asteroids with V < 30 in s0040-2-2
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459390.6521064816 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459397.70245081 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459404.752795139 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459411.8031394677 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (252.0539347, 46.74112368)> <SkyCoord (ICRS): (ra, dec) in deg
#     (276.96609487, 61.67790542)> 2459418.853483796 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-2-2_catalog.csv
# JPL SBI found 31 asteroids with V < 30 in s0040-2-2
# ============================================================
# Sector 40 Camera 2
# ['https://archive.stsci.edu/missions/tess/ffi/s0040/2021/185/2-3/tess2021185054902-s0040-2-3-0211-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59399.244721 from DATE-OBS.
# Set MJD-END to 59399.251665 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459390.6521064816 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459397.70245081 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459404.752795139 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459411.8031394677 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459418.853483796 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-2-3_catalog_elem.csv
# JPL SBI found 51 asteroids with V < 30 in s0040-2-3
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459390.6521064816 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459397.70245081 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459404.752795139 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459411.8031394677 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (260.38248756, 35.66961632)> <SkyCoord (ICRS): (ra, dec) in deg
#     (279.87601949, 49.60396676)> 2459418.853483796 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-2-3_catalog.csv
# JPL SBI found 51 asteroids with V < 30 in s0040-2-3
# ============================================================
# Sector 40 Camera 3
# ['https://archive.stsci.edu/missions/tess/ffi/s0040/2021/185/3-1/tess2021185054902-s0040-3-1-0211-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59399.242354 from DATE-OBS.
# Set MJD-END to 59399.249298 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459390.6521064816 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459397.70245081 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459404.752795139 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459411.8031394677 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459418.853483796 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-3-1_catalog_elem.csv
# JPL SBI found 29 asteroids with V < 30 in s0040-3-1
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459390.6521064816 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459397.70245081 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459404.752795139 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459411.8031394677 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (235.67086839, 57.17046844)> <SkyCoord (ICRS): (ra, dec) in deg
#     (272.41246423, 72.74893273)> 2459418.853483796 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-3-1_catalog.csv
# JPL SBI found 29 asteroids with V < 30 in s0040-3-1
# ============================================================
# Sector 40 Camera 3
# ['https://archive.stsci.edu/missions/tess/ffi/s0040/2021/185/3-2/tess2021185054902-s0040-3-2-0211-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59399.242237 from DATE-OBS.
# Set MJD-END to 59399.249181 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459390.6521064816 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459397.70245081 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459404.752795139 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459411.8031394677 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459418.853483796 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-3-2_catalog_elem.csv
# JPL SBI found 30 asteroids with V < 30 in s0040-3-2
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459390.6521064816 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459397.70245081 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459404.752795139 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459411.8031394677 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (264.3205842, 61.82579399)> <SkyCoord (ICRS): (ra, dec) in deg
#     (305.88807993, 74.33488409)> 2459418.853483796 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-3-2_catalog.csv
# JPL SBI found 30 asteroids with V < 30 in s0040-3-2
# ============================================================
# Sector 40 Camera 3
# ['https://archive.stsci.edu/missions/tess/ffi/s0040/2021/185/3-3/tess2021185054902-s0040-3-3-0211-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59399.240986 from DATE-OBS.
# Set MJD-END to 59399.247930 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459390.6521064816 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459397.70245081 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459404.752795139 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459411.8031394677 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459418.853483796 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-3-3_catalog_elem.csv
# JPL SBI found 74 asteroids with V < 30 in s0040-3-3
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459390.6521064816 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459397.70245081 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459404.752795139 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459411.8031394677 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (223.99333229, 73.59561102)> <SkyCoord (ICRS): (ra, dec) in deg
#     (340.40444619, 86.55411388)> 2459418.853483796 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-3-3_catalog.csv
# JPL SBI found 74 asteroids with V < 30 in s0040-3-3
# ============================================================
# Sector 40 Camera 4
# ['https://archive.stsci.edu/missions/tess/ffi/s0040/2021/185/4-1/tess2021185054902-s0040-4-1-0211-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59399.240020 from DATE-OBS.
# Set MJD-END to 59399.246965 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459390.6521064816 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459397.70245081 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459404.752795139 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459411.8031394677 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459418.853483796 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-4-1_catalog_elem.csv
# JPL SBI found 32 asteroids with V < 30 in s0040-4-1
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459390.6521064816 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459397.70245081 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459404.752795139 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459411.8031394677 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (145.8063163, 69.57379164)> <SkyCoord (ICRS): (ra, dec) in deg
#     (222.41859905, 83.00612025)> 2459418.853483796 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-4-1_catalog.csv
# JPL SBI found 32 asteroids with V < 30 in s0040-4-1
# ============================================================
# Sector 40 Camera 4
# ['https://archive.stsci.edu/missions/tess/ffi/s0040/2021/185/4-2/tess2021185054902-s0040-4-2-0211-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59399.239907 from DATE-OBS.
# Set MJD-END to 59399.246851 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459390.6521064816 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459397.70245081 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459404.752795139 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459411.8031394677 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459418.853483796 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-4-2_catalog_elem.csv
# JPL SBI found 37 asteroids with V < 30 in s0040-4-2
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459390.6521064816 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459397.70245081 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459404.752795139 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459411.8031394677 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0.00021974, 79.66470539)> <SkyCoord (ICRS): (ra, dec) in deg
#     (359.99992689, 89.99760303)> 2459418.853483796 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-4-2_catalog.csv
# JPL SBI found 37 asteroids with V < 30 in s0040-4-2
# ============================================================
# Sector 40 Camera 4
# ['https://archive.stsci.edu/missions/tess/ffi/s0040/2021/185/4-3/tess2021185054902-s0040-4-3-0211-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59399.238826 from DATE-OBS.
# Set MJD-END to 59399.245770 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459390.6521064816 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459397.70245081 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459404.752795139 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459411.8031394677 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459418.853483796 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-4-3_catalog_elem.csv
# JPL SBI found 23 asteroids with V < 30 in s0040-4-3
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459390.6521064816 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459397.70245081 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459404.752795139 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459411.8031394677 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.19352858, 68.52409356)> <SkyCoord (ICRS): (ra, dec) in deg
#     (140.82330754, 81.2052573)> 2459418.853483796 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0040-4-3_catalog.csv
# JPL SBI found 23 asteroids with V < 30 in s0040-4-3
# ============================================================
# Sector 41 Camera 2
# ['https://archive.stsci.edu/missions/tess/ffi/s0041/2021/213/2-1/tess2021213231901-s0041-2-1-0212-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59427.972560 from DATE-OBS.
# Set MJD-END to 59427.979504 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459419.9854282406 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459426.6329947915 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459433.280561343 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459439.9281278937 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459446.5756944446 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-2-1_catalog_elem.csv
# JPL SBI found 43 asteroids with V < 30 in s0041-2-1
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459419.9854282406 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459426.6329947915 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459433.280561343 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459439.9281278937 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (278.21466655, 52.95007828)> <SkyCoord (ICRS): (ra, dec) in deg
#     (309.17688488, 67.7646417)> 2459446.5756944446 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-2-1_catalog.csv
# JPL SBI found 43 asteroids with V < 30 in s0041-2-1
# ============================================================
# Sector 41 Camera 2
# ['https://archive.stsci.edu/missions/tess/ffi/s0041/2021/213/2-2/tess2021213231901-s0041-2-2-0212-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59427.972659 from DATE-OBS.
# Set MJD-END to 59427.979603 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459419.9854282406 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459426.6329947915 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459433.280561343 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459439.9281278937 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459446.5756944446 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-2-2_catalog_elem.csv
# JPL SBI found 35 asteroids with V < 30 in s0041-2-2
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459419.9854282406 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459426.6329947915 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459433.280561343 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459439.9281278937 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (261.64959537, 46.15165178)> <SkyCoord (ICRS): (ra, dec) in deg
#     (288.80120225, 62.57531637)> 2459446.5756944446 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-2-2_catalog.csv
# JPL SBI found 35 asteroids with V < 30 in s0041-2-2
# ============================================================
# Sector 41 Camera 2
# ['https://archive.stsci.edu/missions/tess/ffi/s0041/2021/213/2-3/tess2021213231901-s0041-2-3-0212-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59427.973862 from DATE-OBS.
# Set MJD-END to 59427.980806 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459419.9854282406 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459426.6329947915 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459433.280561343 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459439.9281278937 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459446.5756944446 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-2-3_catalog_elem.csv
# JPL SBI found 53 asteroids with V < 30 in s0041-2-3
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459419.9854282406 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459426.6329947915 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459433.280561343 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459439.9281278937 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (274.28333596, 36.53604045)> <SkyCoord (ICRS): (ra, dec) in deg
#     (296.39320155, 52.0792523)> 2459446.5756944446 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-2-3_catalog.csv
# JPL SBI found 53 asteroids with V < 30 in s0041-2-3
# ============================================================
# Sector 41 Camera 3
# ['https://archive.stsci.edu/missions/tess/ffi/s0041/2021/213/3-1/tess2021213231901-s0041-3-1-0212-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59427.971502 from DATE-OBS.
# Set MJD-END to 59427.978446 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459419.9854282406 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459426.6329947915 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459433.280561343 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459439.9281278937 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459446.5756944446 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-3-1_catalog_elem.csv
# JPL SBI found 24 asteroids with V < 30 in s0041-3-1
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459419.9854282406 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459426.6329947915 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459433.280561343 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459439.9281278937 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (242.68344143, 54.65126538)> <SkyCoord (ICRS): (ra, dec) in deg
#     (277.05724156, 70.53428304)> 2459446.5756944446 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-3-1_catalog.csv
# JPL SBI found 24 asteroids with V < 30 in s0041-3-1
# ============================================================
# Sector 41 Camera 3
# ['https://archive.stsci.edu/missions/tess/ffi/s0041/2021/213/3-2/tess2021213231901-s0041-3-2-0212-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59427.971397 from DATE-OBS.
# Set MJD-END to 59427.978341 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459419.9854282406 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459426.6329947915 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459433.280561343 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459439.9281278937 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459446.5756944446 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-3-2_catalog_elem.csv
# JPL SBI found 31 asteroids with V < 30 in s0041-3-2
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459419.9854282406 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459426.6329947915 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459433.280561343 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459439.9281278937 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (256.12087032, 62.96631151)> <SkyCoord (ICRS): (ra, dec) in deg
#     (302.88269306, 79.03107599)> 2459446.5756944446 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-3-2_catalog.csv
# JPL SBI found 31 asteroids with V < 30 in s0041-3-2
# ============================================================
# Sector 41 Camera 3
# ['https://archive.stsci.edu/missions/tess/ffi/s0041/2021/213/3-3/tess2021213231901-s0041-3-3-0212-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59427.970150 from DATE-OBS.
# Set MJD-END to 59427.977094 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459419.9854282406 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459426.6329947915 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459433.280561343 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459439.9281278937 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459446.5756944446 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-3-3_catalog_elem.csv
# JPL SBI found 29 asteroids with V < 30 in s0041-3-3
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459419.9854282406 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459426.6329947915 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459433.280561343 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459439.9281278937 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (201.53150906, 71.44135149)> <SkyCoord (ICRS): (ra, dec) in deg
#     (290.09583829, 85.64251987)> 2459446.5756944446 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-3-3_catalog.csv
# JPL SBI found 29 asteroids with V < 30 in s0041-3-3
# ============================================================
# Sector 41 Camera 4
# ['https://archive.stsci.edu/missions/tess/ffi/s0041/2021/213/4-1/tess2021213231901-s0041-4-1-0212-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59427.969176 from DATE-OBS.
# Set MJD-END to 59427.976121 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459419.9854282406 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459426.6329947915 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459433.280561343 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459439.9281278937 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459446.5756944446 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-4-1_catalog_elem.csv
# JPL SBI found 22 asteroids with V < 30 in s0041-4-1
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459419.9854282406 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459426.6329947915 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459433.280561343 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459439.9281278937 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (181.45546078, 58.86686414)> <SkyCoord (ICRS): (ra, dec) in deg
#     (217.72743511, 73.50115755)> 2459446.5756944446 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-4-1_catalog.csv
# JPL SBI found 22 asteroids with V < 30 in s0041-4-1
# ============================================================
# Sector 41 Camera 4
# ['https://archive.stsci.edu/missions/tess/ffi/s0041/2021/213/4-2/tess2021213231901-s0041-4-2-0212-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59427.969074 from DATE-OBS.
# Set MJD-END to 59427.976019 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459419.9854282406 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459426.6329947915 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459433.280561343 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459439.9281278937 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459446.5756944446 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-4-2_catalog_elem.csv
# JPL SBI found 23 asteroids with V < 30 in s0041-4-2
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459419.9854282406 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459426.6329947915 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459433.280561343 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459439.9281278937 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (147.06589362, 69.4207621)> <SkyCoord (ICRS): (ra, dec) in deg
#     (215.38766501, 85.2269739)> 2459446.5756944446 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-4-2_catalog.csv
# JPL SBI found 23 asteroids with V < 30 in s0041-4-2
# ============================================================
# Sector 41 Camera 4
# ['https://archive.stsci.edu/missions/tess/ffi/s0041/2021/213/4-3/tess2021213231901-s0041-4-3-0212-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59427.967997 from DATE-OBS.
# Set MJD-END to 59427.974941 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459419.9854282406 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459426.6329947915 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459433.280561343 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459439.9281278937 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459446.5756944446 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-4-3_catalog_elem.csv
# JPL SBI found 23 asteroids with V < 30 in s0041-4-3
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459419.9854282406 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459426.6329947915 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459433.280561343 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459439.9281278937 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (138.46140949, 60.06464121)> <SkyCoord (ICRS): (ra, dec) in deg
#     (178.86574635, 75.75731779)> 2459446.5756944446 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0041-4-3_catalog.csv
# JPL SBI found 23 asteroids with V < 30 in s0041-4-3
# ============================================================
# Sector 42 Camera 2
# ['https://archive.stsci.edu/missions/tess/ffi/s0042/2021/241/2-1/tess2021241084900-s0042-2-1-0213-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59455.372199 from DATE-OBS.
# Set MJD-END to 59455.379143 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (2.34302048, -9.35273779)> <SkyCoord (ICRS): (ra, dec) in deg
#     (17.36351921, 6.01267193)> 2459447.6868055556 30 True
# Requesting JPL Smal-bodies API
# This sector/camera had empty JPL result. NEED to CHECK...
# Sector 42 Camera 2
# ['https://archive.stsci.edu/missions/tess/ffi/s0042/2021/241/2-2/tess2021241084900-s0042-2-2-0213-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59455.372185 from DATE-OBS.
# Set MJD-END to 59455.379129 from DATE-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59455.372742 from DATE-OBS.
# Set MJD-END to 59455.379686 from DATE-END'. [astropy.wcs.wcs]
# This sector/camera has a CCD with bad WCS. NEED to CHECK...
# Sector 42 Camera 2
# ...
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.65416592, 23.68195963)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.6615847, 36.05800076)> 2459498.888171296 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0043-4-1_catalog_elem.csv
# JPL SBI found 20940 asteroids with V < 30 in s0043-4-1
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.65416592, 23.68195963)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.6615847, 36.05800076)> 2459474.165960648 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.65416592, 23.68195963)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.6615847, 36.05800076)> 2459480.34651331 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.65416592, 23.68195963)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.6615847, 36.05800076)> 2459486.527065972 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.65416592, 23.68195963)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.6615847, 36.05800076)> 2459492.707618634 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (73.65416592, 23.68195963)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.6615847, 36.05800076)> 2459498.888171296 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0043-4-1_catalog.csv
# JPL SBI found 20940 asteroids with V < 30 in s0043-4-1
# ============================================================
# Sector 43 Camera 4
# ['https://archive.stsci.edu/missions/tess/ffi/s0043/2021/267/4-2/tess2021267131859-s0043-4-2-0214-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59481.555830 from DATE-OBS.
# Set MJD-END to 59481.562774 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459474.165960648 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459480.34651331 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459486.527065972 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459492.707618634 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459498.888171296 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0043-4-2_catalog_elem.csv
# JPL SBI found 25728 asteroids with V < 30 in s0043-4-2
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459474.165960648 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459480.34651331 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459486.527065972 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459492.707618634 30 False
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (74.89476509, 11.75103528)> <SkyCoord (ICRS): (ra, dec) in deg
#     (87.77595832, 23.65110711)> 2459498.888171296 30 False
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0043-4-2_catalog.csv
# JPL SBI found 25728 asteroids with V < 30 in s0043-4-2
# ============================================================
# Sector 43 Camera 4
# ['https://archive.stsci.edu/missions/tess/ffi/s0043/2021/267/4-3/tess2021267131859-s0043-4-3-0214-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59481.554582 from DATE-OBS.
# Set MJD-END to 59481.561526 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (88.36865938, 11.9163766)> <SkyCoord (ICRS): (ra, dec) in deg
#     (101.13265557, 23.65488787)> 2459474.165960648 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (88.36865938, 11.9163766)> <SkyCoord (ICRS): (ra, dec) in deg
#     (101.13265557, 23.65488787)> 2459480.34651331 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (88.36865938, 11.9163766)> <SkyCoord (ICRS): (ra, dec) in deg
#     (101.13265557, 23.65488787)> 2459486.527065972 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (88.36865938, 11.9163766)> <SkyCoord (ICRS): (ra, dec) in deg
#     (101.13265557, 23.65488787)> 2459492.707618634 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (88.36865938, 11.9163766)> <SkyCoord (ICRS): (ra, dec) in deg
#     (101.13265557, 23.65488787)> 2459498.888171296 30 True
# Requesting JPL Smal-bodies API
# Saving to /Users/jimartin/Work/TESS/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0043-4-3_catalog_elem.csv
# JPL SBI found 31528 asteroids with V < 30 in s0043-4-3
# <SkyCoord (ICRS): (ra, dec) in deg
#     (88.36865938, 11.9163766)> <SkyCoord (ICRS): (ra, dec) in deg
#     (101.13265557, 23.65488787)> 2459474.165960648 30 False
# Requesting JPL Smal-bodies API
# This sector/camera had empty JPL result. NEED to CHECK...
# Sector 44 Camera 2
# ['https://archive.stsci.edu/missions/tess/ffi/s0044/2021/293/2-1/tess2021293062858-s0044-2-1-0215-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59507.273255 from DATE-OBS.
# Set MJD-END to 59507.280200 from DATE-END'. [astropy.wcs.wcs]
# <SkyCoord (ICRS): (ra, dec) in deg
#     (76.82894355, 11.55708581)> <SkyCoord (ICRS): (ra, dec) in deg
#     (89.6098293, 23.78576453)> 2459500.1867824076 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (76.82894355, 11.55708581)> <SkyCoord (ICRS): (ra, dec) in deg
#     (89.6098293, 23.78576453)> 2459506.249279514 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (76.82894355, 11.55708581)> <SkyCoord (ICRS): (ra, dec) in deg
#     (89.6098293, 23.78576453)> 2459512.3117766203 30 True
# Requesting JPL Smal-bodies API
# <SkyCoord (ICRS): (ra, dec) in deg
#     (76.82894355, 11.55708581)> <SkyCoord (ICRS): (ra, dec) in deg
#     (89.6098293, 23.78576453)> 2459518.374273727 30 True
# Requesting JPL Smal-bodies API
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 53
#      51 plt.show()
#      52 try:
# ---> 53     jpl_df = get_asteroid_table(
#      54         edge1,
#      55         edge2,
#      56         sector=sector,
#      57         camera=camera,
#      58         ccd=ccd,
#      59         date_obs=np.linspace(ffi_date.jd.min(), ffi_date.jd.max(), 5),
#      60         force=True,
#      61         elem=True,
#      62         sb_kind="all",
#      63     )
#      64     jpl_df = get_asteroid_table(
#      65         edge1,
#      66         edge2,
#    (...)
#      73         sb_kind="all",
#      74     )
#      75 except ValueError:
#
# File ~/Work/TESS/tess-asteroid-ml/tess_asteroid_ml/make_TESS_asteroid_db.py:174, in get_asteroid_table(edge1, edge2, date_obs, sector, camera, ccd, maglim, save, force, elem, sb_kind)
#     171 for qtime in date_obs:
#     172     print(edge1, edge2, qtime, maglim, elem)
#     173     aux_res.append(
# --> 174         query_jpl_sbi(
#     175             edge1,
#     176             edge2,
#     177             obstime=qtime,
#     178             maglim=maglim,
#     179             elem=elem,
#     180             sb_kind=sb_kind,
#     181         )
#     182     )
#     183 jpl_sb = (
#     184     pd.concat(aux_res)
#     185     .drop_duplicates(subset=["Object name"])
#     186     .reset_index(drop=True)
#     187 )
#     188 if save:
#
# File ~/Work/TESS/tess-asteroid-ml/tess_asteroid_ml/make_TESS_asteroid_db.py:96, in query_jpl_sbi(edge1, edge2, obstime, maglim, elem, sb_kind)
#      94     jpl_sb = pd.concat([x.results.to_pandas() for x in aux_sbid3], axis=0)
#      95 else:
# ---> 96     sbid3 = SBIdent(
#      97         location=xobs_location,
#      98         obstime=obstime,
#      99         fov=[edge1, edge2],
#     100         maglim=maglim,
#     101         precision="high",
#     102         request=True,
#     103         elem=elem,
#     104         filters=filters,
#     105     )
#     106     jpl_sb = sbid3.results.to_pandas()
#     107 if len(jpl_sb) == 0:
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/sbident/sbident.py:202, in SBIdent.__init__(self, location, obstime, fov, precision, hwidth, elem, maglim, magreq, filters, request)
#     199 self.form_uri()
#     201 if request:
# --> 202 	self.make_request()
#     203 else:
#     204 	self.request = False
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/sbident/sbident.py:304, in SBIdent.make_request(self)
#     299 def make_request(self):
#     300 	"""
#     301 	Make the API call and parse return.  Usually for when object instantiated with 'request=False' and thus no API request was made initially.
#     302 	"""
# --> 304 	self.read_uri()
#     305 	self.parse_json()
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/sbident/sbident.py:243, in SBIdent.read_uri(self)
#     238 """
#     239 Makes the API request and checks for warnings or errors in the response.
#     240 """
#     242 # read & set json
# --> 243 response = requests.get(self.uri)
#     244 json = response.json()
#     245 self.json = json
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/tess-asteroid-ml/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Special case

# %%
sector = 24
camera = 4
provider = "mast"


print(f"Sector {sector} Camera {camera}")
# get FFI file path
ffi_file = get_FFI_name(sector=sector, camera=camera, ccd=ccd, provider=provider)
print(ffi_file)

# read FFI to get time, WCS and header
ffi_header, f2d, col_2d, row_2d, ra_2d, dec_2d = get_data_from_files(
    ffi_file, provider=provider
)
ffi_date = Time([ffi_header[0]["DATE-OBS"], ffi_header[0]["DATE-END"]])

ra_2d = np.array(ra_2d)
dec_2d = np.array(dec_2d)
# Out:
# Sector 24 Camera 4
# ['https://archive.stsci.edu/missions/tess/ffi/s0024/2020/120/4-1/tess2020120235919-s0024-4-1-0180-s_ffic.fits', 'https://archive.stsci.edu/missions/tess/ffi/s0024/2020/120/4-2/tess2020120235919-s0024-4-2-0180-s_ffic.fits', 'https://archive.stsci.edu/missions/tess/ffi/s0024/2020/120/4-3/tess2020120235919-s0024-4-3-0180-s_ffic.fits', 'https://archive.stsci.edu/missions/tess/ffi/s0024/2020/120/4-4/tess2020120235919-s0024-4-4-0180-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58968.997099 from DATE-OBS.
# Set MJD-END to 58969.017932 from DATE-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58968.997097 from DATE-OBS.
# Set MJD-END to 58969.017930 from DATE-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58968.996013 from DATE-OBS.
# Set MJD-END to 58969.016846 from DATE-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58968.996016 from DATE-OBS.
# Set MJD-END to 58969.016849 from DATE-END'. [astropy.wcs.wcs]

# %%
# get asteroid table from JPL SBI for Sector/Camera/CCD
edge1 = SkyCoord(np.min(ra_2d[ra_2d >180]) * u.deg, 
                 np.min(dec_2d) * u.deg, 
                 frame='icrs')
edge2 = SkyCoord(np.max(ra_2d[ra_2d < 180]) * u.deg, 
                 np.max(dec_2d) * u.deg, 
                 frame='icrs')

# %%
plt.scatter(ra_2d, dec_2d, s=1)
plt.scatter(edge1.ra, edge1.dec, marker="*", s=4)
plt.scatter(edge2.ra, edge2.dec, marker="*", s=4)
plt.title(f"Sector {sector} camera {camera}")
plt.show()

# %%
try:
    jpl_df = get_asteroid_table(
        edge1, edge2, sector=sector, camera=camera, ccd=ccd, date_obs=ffi_date.mean().jd, force=True
    )
except ValueError:
    print("This sector/camera had empty JPL result. NEED to CHECK...")
# Out:
# Requesting JPL Smal-bodies API
# Saving to /Users/jorgemarpa/Work/BAERI/ADAP/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0024-4-0_catalog.csv
# JPL SBI found 158 asteroids with V < 30 in s0024-4-0

# %% [markdown]
# # Compare old DB vs New with 5 times query

# %%
os.path.dirname(PACKAGEDIR)
# Out:
# '/Users/jorgemarpa/Work/BAERI/ADAP/tess-asteroid-ml'

# %%
db_old = pd.read_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/bkp/jpl_small_bodies_tess_s0002-1-0_catalog.csv")
db_new = pd.read_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/jpl_small_bodies_tess_s0002-1-0_catalog.csv")

db_old.shape, db_new.shape
# Out:
# ((29588, 15), (38135, 15))

# %% [raw]
# db_old = pd.read_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/bkp/jpl_small_bodies_tess_s0002-3-0_catalog.csv")
# db_new = pd.read_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/jpl_small_bodies_tess_s0002-3-0_catalog.csv")
#
# db_old.shape, db_new.shape

# %% [raw]
# db_old = pd.read_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/bkp/jpl_small_bodies_tess_s0002-4-0_catalog.csv")
# db_new = pd.read_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/jpl_small_bodies_tess_s0002-4-0_catalog.csv")
#
# db_old.shape, db_new.shape

# %%
db_old.head()
# Out:
#    Unnamed: 0            Object name Astrometric RA (hh:mm:ss)  \
# 0           0   27 Euterpe (A853 VA)               22:57:17.26
# 1           1   28 Bellona (A854 EA)               22:51:30.46
# 2           2     37 Fides (A855 TB)               22:26:45.60
# 3           3  127 Johanna (A872 VB)               00:04:09.66
# 4           4      173 Ino (A877 PA)               00:04:42.46
#
#   Astrometric Dec (dd mm'ss")  Dist. from center RA (")  \
# 0                 -09:25:58.7                  -30000.0
# 1                 -11:54:48.7                  -30000.0
# 2                 -12:15:41.3                  -50000.0
# 3                 -07:51:52.8                   30000.0
# 4                 -11:13:14.9                   30000.0
#
#    Dist. from center Dec (")  Dist. from center Norm (") Visual magnitude (V)  \
# 0                    50000.0                     57000.0                 9.98
# 1                    40000.0                     52000.0                 11.6
# 2                    40000.0                     67000.0                 10.8
# 3                    50000.0                     61000.0                 12.6
# 4                    40000.0                     51000.0                 10.7
#
#    RA rate ("/h)  Dec rate ("/h)          ra        dec  V_mag         name  \
# 0         -37.23         -13.970  344.321917  -9.432972   9.98   27 Euterpe
# 1         -29.14         -16.330  342.876917 -11.913528  11.60   28 Bellona
# 2         -33.31          -7.776  336.690000 -12.261472  10.80     37 Fides
# 3         -32.55          -8.584    1.040250  -7.864667  12.60  127 Johanna
# 4         -23.00         -32.290    1.176917 -11.220806  10.70      173 Ino
#
#         id
# 0  A853 VA
# 1  A854 EA
# 2  A855 TB
# 3  A872 VB
# 4  A877 PA

# %%
db_old.query("V_mag <= 22.0").shape, db_new.query("V_mag <= 22.0").shape
# Out:
# ((24692, 15), (30935, 15))

# %% [markdown]
# # SBIdent and Comets

# %%
PACKAGEDIR

# %%
keep_cols = ['Object name',
             'Astrometric RA (hh:mm:ss)',
             "Astrometric Dec (dd mm'ss\")", 
             'Visual magnitude (V)', 
             'RA rate ("/h)', 
             'Dec rate ("/h)', 
             'ra', 
             'dec',
             'V_mag', 
             'name', 
             'id', 
             'Absolute magntiude (H)', 
             'Magnitude slope (G)',
             'Eccentricity', 
             'Perihelion (au)', 
             'Time of perihelion passage (JD)',
             'Longitude of ascending node (deg)', 
             'Argument of perihelion (deg)',
             'Inclination (deg)', 
             'Epoch (JD)', 
             'H_mag', 
             'kind',
            ]

# %%
for sector in range(1, 14):
    for camera in range(1, 5):
        # print(f"{sector}-{camera}")
        
        cat = pd.read_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/jpl_small_bodies_tess_s{sector:04}-{camera}-0_catalog.csv", index_col=0)
        elem = pd.read_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/jpl_small_bodies_tess_s{sector:04}-{camera}-0_catalog_elem.csv", index_col=0)
        comet = pd.read_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/jpl_small_bodies_tess_s{sector:04}-{camera}-0_catalog_comet.csv", index_col=0)
        
        df = pd.merge(cat, elem, on=["Object name", "name", "id"], how="outer")
        df["kind"] = "a"
        mask = np.isin(df.id.values, comet.id.values)
        df["kind"][mask] = "c"
        
        # print(df.kind.value_counts())
        
        df.loc[:, keep_cols].to_csv(f"{os.path.dirname(PACKAGEDIR)}/data/jpl/merged/jpl_small_bodies_tess_s{sector:04}-{camera}-0_catalog.csv")
# Out:
# 1-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    40639
# c       31
# Name: kind, dtype: int64
# 1-2
# a    6150
# c      10
# Name: kind, dtype: int64
# 1-3
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    2025
# c      26
# Name: kind, dtype: int64
# 1-4
# a    322
# c     18
# Name: kind, dtype: int64
# 2-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    38102
# c       32
# Name: kind, dtype: int64
# 2-2
# a    5042
# c      17
# Name: kind, dtype: int64
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2-3
# a    1323
# c      12
# Name: kind, dtype: int64
# 2-4
# a    412
# c     18
# Name: kind, dtype: int64
# 3-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    37067
# c       15
# Name: kind, dtype: int64
# 3-2
# a    3983
# c       8
# Name: kind, dtype: int64
# 3-3
# a    752
# c     10
# Name: kind, dtype: int64
# 3-4
# a    361
# c     16
# Name: kind, dtype: int64
# 4-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    33950
# c       16
# Name: kind, dtype: int64
# 4-2
# a    2977
# c      11
# Name: kind, dtype: int64
# 4-3
# a    451
# c     11
# Name: kind, dtype: int64
# 4-4
# a    234
# c     16
# Name: kind, dtype: int64
# 5-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    27263
# c       16
# Name: kind, dtype: int64
# 5-2
# a    2121
# c       9
# Name: kind, dtype: int64
# 5-3
# a    257
# c      7
# Name: kind, dtype: int64
# 5-4
# a    228
# c     15
# Name: kind, dtype: int64
# 6-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    20130
# c       10
# Name: kind, dtype: int64
# 6-2
# a    1709
# c       2
# Name: kind, dtype: int64
# 6-3
# a    181
# c      6
# Name: kind, dtype: int64
# 6-4
# a    310
# c     33
# Name: kind, dtype: int64
# 7-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    27673
# c       26
# Name: kind, dtype: int64
# 7-2
# a    2057
# c       4
# Name: kind, dtype: int64
# 7-3
# a    213
# c      8
# Name: kind, dtype: int64
# 7-4
# a    179
# c     14
# Name: kind, dtype: int64
# 8-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    34210
# c        7
# Name: kind, dtype: int64
# 8-2
# a    2393
# c       6
# Name: kind, dtype: int64
# 8-3
# a    267
# c     14
# Name: kind, dtype: int64
# 8-4
# a    180
# c     16
# Name: kind, dtype: int64
# 9-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    38753
# c       18
# Name: kind, dtype: int64
# 9-2
# a    3109
# c      18
# Name: kind, dtype: int64
# 9-3
# a    412
# c     16
# Name: kind, dtype: int64
# 9-4
# a    942
# c     35
# Name: kind, dtype: int64
# 10-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    42339
# c       23
# Name: kind, dtype: int64
# 10-2
# a    4068
# c      25
# Name: kind, dtype: int64
# 10-3
# a    849
# c     21
# Name: kind, dtype: int64
# 10-4
# a    205
# c     21
# Name: kind, dtype: int64
# 11-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    39046
# c       20
# Name: kind, dtype: int64
# 11-2
# a    4690
# c      21
# Name: kind, dtype: int64
# 11-3
# a    1296
# c      27
# Name: kind, dtype: int64
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 11-4
# a    209
# c     20
# Name: kind, dtype: int64
# 12-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    31356
# c       25
# Name: kind, dtype: int64
# 12-2
# a    4330
# c      25
# Name: kind, dtype: int64
# 12-3
# a    253
# c     13
# Name: kind, dtype: int64
# 12-4
# a    307
# c     20
# Name: kind, dtype: int64
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 13-1
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# a    30778
# c       17
# Name: kind, dtype: int64
# 13-2
# a    4255
# c      21
# Name: kind, dtype: int64
# 13-3
# a    215
# c     11
# Name: kind, dtype: int64
# 13-4
# a    391
# c     21
# Name: kind, dtype: int64
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
