# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
import matplotlib.pyplot as plt

from tess_asteroid_ml.make_TESS_asteroid_db import *
from tess_ephem import TessEphem

# %% [markdown]
# s 14 - 26: cam 2-4 Done
# s 14-20: cam 1 done

# %%
for sector in range(4, 6):
    for camera in range(2, 3):
        create_FFI_asteroid_database(
            sector=sector, 
            camera=camera, 
            ccd=0, 
            maglim=24, 
            provider="mast", 
            plot=True,
        )
# Out:
# ['https://archive.stsci.edu/missions/tess/ffi/s0004/2018/307/2-1/tess2018307065939-s0004-2-1-0124-s_ffic.fits', 'https://archive.stsci.edu/missions/tess/ffi/s0004/2018/307/2-2/tess2018307065939-s0004-2-2-0124-s_ffic.fits', 'https://archive.stsci.edu/missions/tess/ffi/s0004/2018/307/2-3/tess2018307065939-s0004-2-3-0124-s_ffic.fits', 'https://archive.stsci.edu/missions/tess/ffi/s0004/2018/307/2-4/tess2018307065939-s0004-2-4-0124-s_ffic.fits']
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58425.295207 from DATE-OBS.
# Set MJD-END to 58425.316040 from DATE-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58425.295258 from DATE-OBS.
# Set MJD-END to 58425.316091 from DATE-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58425.296096 from DATE-OBS.
# Set MJD-END to 58425.316929 from DATE-END'. [astropy.wcs.wcs]
# ...

# %%
# !open /Users/jorgemarpa/Work/BAERI/ADAP/tess-asteroid-ml/data/figures/tess-ffi_s0004-2-0_diagnostic_plot.pdf
