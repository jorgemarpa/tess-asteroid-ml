# %%
import os, re
import argparse

import numpy as np
import pandas as pd
import lightkurve as lk

from tess_asteroid_ml import *
from tess_asteroid_ml.make_TESS_asteroid_db import *
from tess_asteroid_ml.utils import in_cutout, power_find
from tess_asteroid_ml.make_TESScut_asteroids import *

import warnings
warnings.simplefilter('ignore')
# Out:
# /Users/jorgemarpa/.pyenv/versions/tess-test/lib/python3.9/site-packages/lightkurve/config/__init__.py:119: UserWarning: The default Lightkurve cache directory, used by download(), etc., has been moved to /Users/jorgemarpa/.lightkurve/cache. Please move all the files in the legacy directory /Users/jorgemarpa/.lightkurve-cache to the new location and remove the legacy directory. Refer to https://docs.lightkurve.org/reference/config.html#default-cache-directory-migration for more information.
#   warnings.warn(

# %%
# %pdb off
# Out:
# Automatic pdb calling has been turned OFF

# %%
make_asteroid_cut_data(
    sector=26,
    camera=3,
    ccd=3,
    sampling="sparse",
    fit_bkg=False,
    limiting_mag=22,
    cutout_size=64,
    verbose=True,
    plot=False,
    download=False,
)
# Out:
# Working on FFI sector 26 camera 3 ccd 3
# FFI file is https://archive.stsci.edu/missions/tess/ffi/s0026/2020/174/3-3/tess2020174155917-s0026-3-3-0188-s_ffic.fits
# /Users/jorgemarpa/Work/BAERI/ADAP/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0026-3-0_catalog.csv
# Loading from CSV file: /Users/jorgemarpa/Work/BAERI/ADAP/tess-asteroid-ml/data/jpl/jpl_small_bodies_tess_s0026-3-0_catalog.csv
# JPL SBI found 138 asteroids with V < 30 in s0026-3-0
# Asteroid table has 32 items with V < 22
# Asteroid track DB has 20 available
# Working with FFI row 3/33 and 33 cuts...
# TESS cut files row 212:  33%|███████████████████▎                                      | 11/33 [00:35<01:11,  3.23s/it]
# {1: Object name    (2012 KF47)
# V_mag                 20.5
# Name: 72, dtype: object}
# TESS cut files row 212: 100%|██████████████████████████████████████████████████████████| 33/33 [01:46<00:00,  3.23s/it]
# Working with FFI row 5/33 and 33 cuts...
# TESS cut files row 330:  36%|█████████████████████                                     | 12/33 [00:37<01:06,  3.15s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 make_asteroid_cut_data(
#       2     sector=26,
#       3     camera=3,
#       4     ccd=3,
#       5     sampling="sparse",
#       6     fit_bkg=False,
#       7     limiting_mag=22,
#       8     cutout_size=64,
#       9     verbose=True,
#      10     plot=False,
#      11     download=False,
#      12 )
#
# File ~/Work/BAERI/ADAP/tess-asteroid-ml/tess_asteroid_ml/make_TESScut_asteroids.py:305, in make_asteroid_cut_data(sector, camera, ccd, sampling, fit_bkg, limiting_mag, cutout_size, verbose, plot, download)
#     299 sb_ephems_highres = {}
#     300 for q, ff in tqdm(
#     301     enumerate(tpf_names),
#     302     total=len(tpf_names),
#     303     desc=f"TESS cut files row {nrow + 1}",
#     304 ):
# --> 305     fficut_aster = AsteroidTESScut(lk.read(ff, quality_bitmask=None))
#     306     fficut_aster.ffi_exp_time = (
#     307         (ffi_header["TSTOP"] - ffi_header["TSTART"]) * 24 * 3600
#     308     )
#     309     fficut_aster.get_CBVs(align=False, interpolate=True)
#
# File ~/Work/BAERI/ADAP/tess-asteroid-ml/tess_asteroid_ml/asteroid_tess_ccut.py:113, in AsteroidTESScut.__init__(self, tpf, target, sector, cutout_size, quality_bitmask, use_tike)
#     111 self.column = self.column.ravel()
#     112 self.row = self.row.ravel()
# --> 113 self.ra, self.dec = self.tpf.get_coordinates(cadence=0)
#     114 self.ra = self.ra.ravel()
#     115 self.dec = self.dec.ravel()
#
# File ~/.pyenv/versions/tess-test/lib/python3.9/site-packages/lightkurve/targetpixelfile.py:481, in TargetPixelFile.get_coordinates(self, cadence)
#     476 Y = np.atleast_3d(Y).transpose([2, 0, 1]) + np.atleast_3d(
#     477     pos_corr2_pix
#     478 ).transpose([1, 2, 0])
#     480 # Pass through WCS
# --> 481 ra, dec = w.wcs_pix2world(X.ravel(), Y.ravel(), 1)
#     482 ra = ra.reshape((pos_corr1_pix.shape[0], self.shape[1], self.shape[2]))
#     483 dec = dec.reshape((pos_corr2_pix.shape[0], self.shape[1], self.shape[2]))
#
# File ~/.pyenv/versions/tess-test/lib/python3.9/site-packages/astropy/wcs/wcs.py:1641, in WCS.wcs_pix2world(self, *args, **kwargs)
#    1639 if self.wcs is None:
#    1640     raise ValueError("No basic WCS settings were created.")
# -> 1641 return self._array_converter(
#    1642     lambda xy, o: self.wcs.p2s(xy, o)["world"], "output", *args, **kwargs
#    1643 )
#
# File ~/.pyenv/versions/tess-test/lib/python3.9/site-packages/astropy/wcs/wcs.py:1560, in WCS._array_converter(self, func, sky, ra_dec_order, *args)
#    1554     except Exception:
#    1555         raise TypeError(
#    1556             "When providing more than two arguments, they must be "
#    1557             + "a 1-D array for each axis, followed by an origin."
#    1558         )
# -> 1560     return _return_list_of_arrays(axes, origin)
#    1562 raise TypeError(
#    1563     f"WCS projection has {self.naxis} dimensions, so expected 2 (an Nx{self.naxis} array "
#    1564     f"and the origin argument) or {self.naxis + 1} arguments (the position in each "
#    1565     f"dimension, and the origin argument). Instead, {len(args)} arguments were "
#    1566     "given."
#    1567 )
#
# File ~/.pyenv/versions/tess-test/lib/python3.9/site-packages/astropy/wcs/wcs.py:1510, in WCS._array_converter.<locals>._return_list_of_arrays(axes, origin)
#    1508 if ra_dec_order and sky == "input":
#    1509     xy = self._denormalize_sky(xy)
# -> 1510 output = func(xy, origin)
#    1511 if ra_dec_order and sky == "output":
#    1512     output = self._normalize_sky(output)
#
# File ~/.pyenv/versions/tess-test/lib/python3.9/site-packages/astropy/wcs/wcs.py:1642, in WCS.wcs_pix2world.<locals>.<lambda>(xy, o)
#    1639 if self.wcs is None:
#    1640     raise ValueError("No basic WCS settings were created.")
#    1641 return self._array_converter(
# -> 1642     lambda xy, o: self.wcs.p2s(xy, o)["world"], "output", *args, **kwargs
#    1643 )
#
# KeyboardInterrupt:
